# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
# Questões A e C.
fig = plt.figure(figsize=(15,5)) # Tamanho da figura
eixo = fig.add_axes([0,0,1,1]) # Eixos do gráfico
eixo.plot(df['data'],df['humidade'],color='b') # Dados no gráfico
eixo.grid(True) # Vai ter grades
eixo.set_title('UMIDADE x ANO',fontsize=20,pad=20) # Titulo do gráfico
eixo.set_ylabel('UMIDADE',fontsize=18) # legenda eixo Y
eixo.set_xlabel('ANO',fontsize=18) # legenda eixo X
eixo.legend(['UMIDADE'],loc='best') # legenda dos dados

# %%
# Questão B.
fig = plt.figure(figsize=(15,5)) # Tamanho da figura
eixo = fig.add_axes([0,0,1,1]) # Eixos do gráfico
eixo.plot(df['data'],df['velocidade do vento'],color='b') # Dados no gráfico
eixo.grid(True) # Vai ter grades
eixo.set_title('VELOCIDADE DO VENTO x ANO',fontsize=20,pad=20) # Titulo do gráfico
eixo.set_ylabel('VELOCIDADE DO VENTO',fontsize=18) # legenda eixo Y
eixo.set_xlabel('ANO',fontsize=18) # legenda eixo X
eixo.legend(['velocidade do vento'],loc='best') # legenda dos dados

# %%
# Questão D.
fig = plt.figure(figsize=(15,5)) # Tamanho da figura
eixo = fig.add_axes([0,0,1,1]) # Eixos do gráfico
eixo.plot(df['data'],df['direção do vento'],color='b') # Dados no gráfico
eixo.grid(True) # Vai ter grades
eixo.set_title('DIREÇÃO DO VENTO',fontsize=20,pad=20) # Titulo do gráfico
eixo.set_ylabel('DIREÇÃO DO VENTO',fontsize=18) # legenda eixo Y
eixo.set_xlabel('ANO',fontsize=18) # legenda eixo X
eixo.legend(['DIREÇÃO DO VENTO'],loc='best') # legenda dos dados

# %%
# Questão E.
fig = plt.figure(figsize=(15,5)) # Tamanho da figura
eixo = fig.add_axes([0,0,1,1]) # Eixos do gráfico
eixo.plot(df['data'],df['pressão'],color='b') # Dados no gráfico
eixo.grid(True) # Vai ter grades
eixo.set_title('PRESSÃO',fontsize=20,pad=20) # Titulo do gráfico
eixo.set_ylabel('PRESSÃO',fontsize=18) # legenda eixo Y
eixo.set_xlabel('ANO',fontsize=18) # legenda eixo X
eixo.legend(['PRESSÃO'],loc='best') # legenda dos dados

# %%
# Questão F.
plt.boxplot(df['humidade'])
plt.xlabel('Eixo x')
plt.ylabel('UMIDADE')
plt.show()

# %%
# Questão G.
plt.boxplot(df['direção do vento'])
plt.xlabel('Eixo x')
plt.ylabel('DIREÇÃO DO VENTO')
plt.show()

# %%
# Questão H.
plt.boxplot(df['pressão'])
plt.xlabel('Eixo x')
plt.ylabel('PRESSÃO')
plt.show()
